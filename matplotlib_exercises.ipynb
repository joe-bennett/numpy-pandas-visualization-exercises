# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# %% [markdown]
# Use matplotlib to plot the following equation:
#
# y=x^2−x+2
#
# You'll need to write the code that generates the x and y points.
#
# Add an anotation for the point 0, 0, the origin.

# %%
#x = np.linspace(-np.pi,np.pi,100)
x = np.array(range(-50,150))
y=(x**2) - x + 2
plt.plot(x,y)
#plt.text(0.,4, 'the origin')
plt.annotate('the origin', xy= (0,0), xytext=(-2.5,10000), arrowprops={'facecolor':'blue'})
plt.show()

# %% [markdown]
# Create and label 4 separate charts for the following equations (choose a range for x that makes sense):
#
# y=√x
#
# y=x^3
#
# y=2^x
#
# y=1/(x+1)

# %%
x= list(range(50))
y=np.sqrt(x)
plt.plot(x,y, c= 'red')
plt.title('chart for $y = sqrt(x)$')
plt.show()



x= np.array(range(-50,50))
y=np.power(x,3)
plt.plot(x,y)
plt.title('chart for $y = x^3$')
plt.show()

x= np.array(range(0,100))
y=np.power(2,x)
plt.plot(x,y)
plt.title('chart for $y = 2^x$')
plt.show()



x=np.array(range(0,100))
y=1/(x+1)
plt.plot(x,y)
plt.title('chart for y=1/(x+1)')
plt.show()

# %% [markdown]
# 3. Combine the figures you created in the last step into one large figure with 4 subplots.

# %%
x= list(range(10))
plt.subplot(221)
y=np.sqrt(x)
plt.plot(x,y, c= 'red')
plt.title('chart for $y = sqrt(x)$')




x= np.array(range(0,10))
#y=np.power(x,3)
plt.subplot(222)
y = x**3
plt.plot(x,y)
plt.title('chart for $y = x^3$')


x= np.array(range(0,10))
#y=np.power(2,x)
plt.subplot(223)
y=2**x
plt.plot(x,y)
plt.title('chart for $y = 2^x$')




x=np.array(range(0,10))
plt.subplot(224)
y=1/(x+1)
plt.plot(x,y)
plt.title('chart for y=1/(x+1)')

plt.suptitle ('subplots demo')

plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)

plt.show()

# %% [markdown]
# 4. Combine the figures you created in the last step into one figure where each of the 4 equations has a different color for the points. Be sure to include a legend and an appropriate title for the figure.

# %%
plt.figure(figsize=(10,10))


#x= list(range(50))
y=np.sqrt(x)
plt.plot(x,y, c= 'red')





x= np.array(range(0,50))
y=np.power(x,3)
plt.plot(x,y, c= 'yellow')



#x= np.array(range(0,100))
y=2**x
plt.plot(x,y, c= 'orange')





#x=np.array(range(0,100))
y=1/(x+1)
plt.plot(x,y, c= 'blue')


plt.title('four functions in one figure')

plt.ylim(-2,10)
plt.xlim(-100,120)
plt.show()
